# %%
data one;
infile "C:\Users\user\Downloads\longanal110sp1.dat";
input id month1-month5 y;
run;
# Out:
# 17                                                            SAS 系統                        2022年 4月17日 星期日 上午11時03分40秒
#
# 102        ods listing close;ods html5 (id=saspy_internal) file=_tomods1 options(bitmap_mode='inline') device=svg style=HTMLBlue;
# 102      ! ods graphics on / outputfmt=png;
# NOTE: Writing HTML5(SASPY_INTERNAL) Body file: _TOMODS1
# 103
# 104        data one;
# 105        infile "C:\Users\user\Downloads\longanal110sp1.dat";
# 106        input id month1-month5 y;
# 107        run;
#
# NOTE: The infile "C:\Users\user\Downloads\longanal110sp1.dat" is:
#       檔案名稱=C:\Users\user\Downloads\longanal110sp1.dat,
#       RECFM=V,LRECL=32767,File Size (bytes)=3800,
#       上次修改時間=2022年04月16日 20時03分11秒,
#       Create Time=2022年04月16日 20時03分11秒
#
# NOTE: 100 records were read from the infile "C:\Users\user\Downloads\longanal110sp1.dat".
#       The minimum record length was 37.
#       The maximum record length was 37.
# ...

# %%
proc print data = one;
run;
# Out:
# <!DOCTYPE html>
# <html lang="zh" xml:lang="zh" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS 輸出</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...
